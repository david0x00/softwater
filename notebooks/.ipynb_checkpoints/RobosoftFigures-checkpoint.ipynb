# %%
import pandas as pd
import numpy as np
import sklearn
from keras.models import Sequential
from keras.layers import Dense, Dropout, Masking, Embedding
from matplotlib import pyplot as plt
from ipywidgets import interact
import pickle
import math
from IPython.display import clear_output
plt.rcParams['figure.dpi'] = 200

# %% [markdown]
# # Data In

# %%
all_df_norm = pd.read_csv("data/all_df_basic_norm.csv")
norm_bounds = pd.read_csv("data/norm_bounds_basic.csv")
all_df = pd.read_csv("data/all_df_basic.csv")
all_df_shuffled, all_df_norm_shuffled = sklearn.utils.shuffle(all_df, all_df_norm)

# %% [markdown]
# ### Data Segmenter

# %%
def segment_data(data, x_labels, y_labels, split_factor=0.8):
    x_data = data[x_labels]
    y_data = data[y_labels]

    x_dim = len(x_labels)
    y_dim = len(y_labels)

    split = int(split_factor * len(x_data))

    x_train = x_data[:split]
    y_train = y_data[:split]

    x_test = x_data[split:]
    y_test = y_data[split:]
    return x_train, y_train, x_test, y_test, x_dim, y_dim

# %% [markdown]
# # Learned Forward Kinematics

# %% [markdown]
# ### Data Labels

# %%
fk_x_labels = ["M1-PL", "M1-PR", "M2-PL", "M2-PR",
            "M1-AL-IN-ACT", "M1-AR-IN-ACT", "M2-AL-IN-ACT", "M2-AR-IN-ACT",
            "M1-AL-OUT", "M1-AR-OUT", "M2-AL-OUT", "M2-AR-OUT"]
lookback = 3
new_x_labels = []
for i in range(lookback):
    for l in fk_x_labels:
        new_x_labels.append(l + str(i))
fk_x_labels += new_x_labels

fk_y_labels = ["M1X", "M1Y", "M2X", "M2Y", "M3X", "M3Y",
            "M4X", "M4Y", "M5X", "M5Y", "M6X", "M6Y",
            "M7X", "M7Y", "M8X", "M8Y", "M9X", "M9Y",
            "M10X", "M10Y"]

fk_x_train, fk_y_train, fk_x_test, fk_y_test, fk_x_dim, fk_y_dim = segment_data(all_df_norm_shuffled, fk_x_labels, fk_y_labels, split_factor=0.8)
# Out:
#          M1-PL     M1-PR     M2-PL     M2-PR  M1-AL-IN-ACT  M1-AR-IN-ACT  \
# 2590  0.128000  0.138077  0.195308  0.706115             0             0
# 352   0.298192  0.201808  0.224615  0.209000             0             0
# 85    0.280154  0.638346  0.229692  0.213077             1             0
# 2829  0.134731  0.127731  0.487115  0.225577             0             0
# 2473  0.128231  0.128231  0.202269  0.211885             0             0
# ...        ...       ...       ...       ...           ...           ...
# 434   0.219346  0.192423  0.221038  0.209000             0             0
# 295   0.288346  0.318615  0.224615  0.209231             0             0
# 213   0.233269  0.663808  0.214769  0.218154             0             0
# 2052  0.150115  0.114269  0.486654  0.197000             0             0
# 2851  0.130615  0.131115  0.357308  0.227038             0             0
#
#       M2-AL-IN-ACT  M2-AR-IN-ACT  M1-AL-OUT  M1-AR-OUT  ...    M2-PL2  \
# 2590             0             0          0          0  ...  0.194346
# 352              0             0          1          0  ...  0.224615
# 85               0             0          0          0  ...  0.216923
# 2829             0             0          0          0  ...  0.701077
# 2473             0             0          0          0  ...  0.218846
# ...            ...           ...        ...        ...  ...       ...
# 434              0             0          0          1  ...  0.218615
# 295              0             0          0          1  ...  0.221269
# 213              0             0          1          0  ...  0.213577
# 2052             1             0          0          0  ...  0.321269
# 2851             0             0          0          0  ...  0.479923
#
#         M2-PR2  M1-AL-IN-ACT2  M1-AR-IN-ACT2  M2-AL-IN-ACT2  M2-AR-IN-ACT2  \
# 2590  0.602769              0              0              0              1
# 352   0.209231              0              0              0              0
# 85    0.221500              0              1              0              0
# 2829  0.211423              0              0              0              0
# 2473  0.211423              0              0              0              0
# ...        ...            ...            ...            ...            ...
# 434   0.210192              0              0              0              0
# 295   0.209231              0              0              0              0
# 213   0.218615              0              0              0              0
# 2052  0.200577              0              0              1              0
# 2851  0.225577              0              0              0              0
#
#       M1-AL-OUT2  M1-AR-OUT2  M2-AL-OUT2  M2-AR-OUT2
# 2590           0           0           0           0
# 352            0           1           0           0
# 85             0           0           0           0
# 2829           0           0           0           0
# 2473           0           0           1           0
# ...          ...         ...         ...         ...
# 434            0           1           0           0
# 295            0           1           0           0
# 213            1           0           0           0
# 2052           0           0           0           0
# 2851           0           0           1           0
#
# [2699 rows x 48 columns]

# %% [markdown]
# ### Model Structure

# %%
fmodel = Sequential()
fmodel.add(Dense(128, input_dim=fk_x_dim, activation='relu'))
fmodel.add(Dropout(0.2))
fmodel.add(Dense(64, activation='relu'))
fmodel.add(Dropout(0.2))
fmodel.add(Dense(32, activation='relu'))
fmodel.add(Dropout(0.2))
fmodel.add(Dense(16, activation='relu'))
fmodel.add(Dropout(0.2))
fmodel.add(Dense(fk_y_dim, activation='relu'))

fmodel.compile(loss='mse', optimizer='adam', metrics=['accuracy'])
fmodel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               6272
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 16)                528
#
#  dropout_3 (Dropout)         (None, 16)                0
#
#  dense_4 (Dense)             (None, 20)                340
#
# =================================================================
# Total params: 17,476
# Trainable params: 17,476
# Non-trainable params: 0
# _________________________________________________________________

# %%
historyf = fmodel.fit(fk_x_train, fk_y_train, epochs=100, batch_size=8)
# Out:
# Epoch 1/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0424 - accuracy: 0.3212
# Epoch 2/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0084 - accuracy: 0.5954
# Epoch 3/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0053 - accuracy: 0.7292
# Epoch 4/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0038 - accuracy: 0.7666
# Epoch 5/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0029 - accuracy: 0.8207
# Epoch 6/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0024 - accuracy: 0.8396
# Epoch 7/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0021 - accuracy: 0.8544
# Epoch 8/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0018 - accuracy: 0.8607
# Epoch 9/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0016 - accuracy: 0.8740
# Epoch 10/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0016 - accuracy: 0.8766
# Epoch 11/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0014 - accuracy: 0.8722
# Epoch 12/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.8829
# Epoch 13/100
# 338/338 [==============================] - 1s 3ms/step - loss: 0.0013 - accuracy: 0.8744
# Epoch 14/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.8792
# Epoch 15/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.8881
# Epoch 16/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.8914
# Epoch 17/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 0.8859
# Epoch 18/100
# 338/338 [==============================] - 1s 3ms/step - loss: 0.0011 - accuracy: 0.8892
# Epoch 19/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0011 - accuracy: 0.8966
# Epoch 20/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0010 - accuracy: 0.8914
# Epoch 21/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0010 - accuracy: 0.8955
# Epoch 22/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0010 - accuracy: 0.8989
# Epoch 23/100
# 338/338 [==============================] - 1s 2ms/step - loss: 9.9265e-04 - accuracy: 0.8948
# Epoch 24/100
# 338/338 [==============================] - 1s 2ms/step - loss: 9.8764e-04 - accuracy: 0.8951
# Epoch 25/100
# 338/338 [==============================] - 1s 3ms/step - loss: 9.2171e-04 - accuracy: 0.9022
# Epoch 26/100
# 338/338 [==============================] - 1s 3ms/step - loss: 9.1568e-04 - accuracy: 0.8963
# Epoch 27/100
# 338/338 [==============================] - 1s 3ms/step - loss: 9.8180e-04 - accuracy: 0.9003
# Epoch 28/100
# 338/338 [==============================] - 1s 3ms/step - loss: 9.4141e-04 - accuracy: 0.9048
# Epoch 29/100
# 338/338 [==============================] - 1s 2ms/step - loss: 8.9814e-04 - accuracy: 0.8940
# Epoch 30/100
# 338/338 [==============================] - 1s 2ms/step - loss: 8.8125e-04 - accuracy: 0.9003
# Epoch 31/100
# 338/338 [==============================] - 1s 2ms/step - loss: 8.8633e-04 - accuracy: 0.9033
# Epoch 32/100
# 338/338 [==============================] - 1s 2ms/step - loss: 9.4652e-04 - accuracy: 0.8940
# Epoch 33/100
# 338/338 [==============================] - 1s 2ms/step - loss: 8.6754e-04 - accuracy: 0.8992
# Epoch 34/100
# 338/338 [==============================] - 1s 2ms/step - loss: 8.9574e-04 - accuracy: 0.8907
# Epoch 35/100
# 338/338 [==============================] - 1s 2ms/step - loss: 8.4576e-04 - accuracy: 0.8974
# Epoch 36/100
# 338/338 [==============================] - 1s 2ms/step - loss: 8.8297e-04 - accuracy: 0.8966
# Epoch 37/100
# 338/338 [==============================] - 1s 2ms/step - loss: 8.4861e-04 - accuracy: 0.8944
# Epoch 38/100
# 338/338 [==============================] - 1s 2ms/step - loss: 8.5793e-04 - accuracy: 0.8977
# Epoch 39/100
# 338/338 [==============================] - 1s 2ms/step - loss: 8.3205e-04 - accuracy: 0.8885
# Epoch 40/100
# 338/338 [==============================] - 1s 2ms/step - loss: 8.1184e-04 - accuracy: 0.9052
# Epoch 41/100
# 338/338 [==============================] - 1s 2ms/step - loss: 8.7088e-04 - accuracy: 0.8922
# Epoch 42/100
# 338/338 [==============================] - 1s 2ms/step - loss: 8.4604e-04 - accuracy: 0.9011
# Epoch 43/100
# 338/338 [==============================] - 1s 2ms/step - loss: 8.6020e-04 - accuracy: 0.9003
# Epoch 44/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.8286e-04 - accuracy: 0.8959
# Epoch 45/100
# 338/338 [==============================] - 1s 2ms/step - loss: 8.5353e-04 - accuracy: 0.9000
# Epoch 46/100
# 338/338 [==============================] - 1s 3ms/step - loss: 8.5274e-04 - accuracy: 0.9044
# Epoch 47/100
# 338/338 [==============================] - 1s 2ms/step - loss: 8.3663e-04 - accuracy: 0.9000
# Epoch 48/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.9807e-04 - accuracy: 0.9077
# Epoch 49/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.9958e-04 - accuracy: 0.9048
# Epoch 50/100
# 338/338 [==============================] - 1s 2ms/step - loss: 8.4700e-04 - accuracy: 0.8929
# Epoch 51/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.9753e-04 - accuracy: 0.9003
# Epoch 52/100
# 338/338 [==============================] - 1s 2ms/step - loss: 8.0754e-04 - accuracy: 0.9000
# Epoch 53/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.9579e-04 - accuracy: 0.9029
# Epoch 54/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.6757e-04 - accuracy: 0.9066
# Epoch 55/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.9941e-04 - accuracy: 0.9029
# Epoch 56/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.9083e-04 - accuracy: 0.8970
# Epoch 57/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.7988e-04 - accuracy: 0.9040
# Epoch 58/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.4258e-04 - accuracy: 0.8989
# Epoch 59/100
# 338/338 [==============================] - 1s 2ms/step - loss: 8.2103e-04 - accuracy: 0.9011
# Epoch 60/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.6785e-04 - accuracy: 0.8989
# Epoch 61/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.5372e-04 - accuracy: 0.9040
# Epoch 62/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.6727e-04 - accuracy: 0.9026
# Epoch 63/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.9749e-04 - accuracy: 0.8966
# Epoch 64/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.6843e-04 - accuracy: 0.8955
# Epoch 65/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.7497e-04 - accuracy: 0.9074
# Epoch 66/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.7573e-04 - accuracy: 0.8996
# Epoch 67/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.6631e-04 - accuracy: 0.9044
# Epoch 68/100
# 338/338 [==============================] - 1s 2ms/step - loss: 8.1265e-04 - accuracy: 0.9085
# Epoch 69/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.5863e-04 - accuracy: 0.8933
# Epoch 70/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.3314e-04 - accuracy: 0.9074
# Epoch 71/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.9510e-04 - accuracy: 0.9085
# Epoch 72/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.4274e-04 - accuracy: 0.9003
# Epoch 73/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.6360e-04 - accuracy: 0.9022
# Epoch 74/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.6885e-04 - accuracy: 0.9103
# Epoch 75/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.5172e-04 - accuracy: 0.9029
# Epoch 76/100
# 338/338 [==============================] - 1s 3ms/step - loss: 7.5506e-04 - accuracy: 0.8996
# Epoch 77/100
# 338/338 [==============================] - 1s 3ms/step - loss: 7.3104e-04 - accuracy: 0.9007
# Epoch 78/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.6667e-04 - accuracy: 0.9029
# Epoch 79/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.1585e-04 - accuracy: 0.9129
# Epoch 80/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.4196e-04 - accuracy: 0.9014
# Epoch 81/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.4779e-04 - accuracy: 0.9033
# Epoch 82/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.5715e-04 - accuracy: 0.8989
# Epoch 83/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.1486e-04 - accuracy: 0.9155
# Epoch 84/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.0478e-04 - accuracy: 0.9059
# Epoch 85/100
# 338/338 [==============================] - 1s 2ms/step - loss: 6.6156e-04 - accuracy: 0.9185
# Epoch 86/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.5005e-04 - accuracy: 0.9096
# Epoch 87/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.4958e-04 - accuracy: 0.9133
# Epoch 88/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.3143e-04 - accuracy: 0.9085
# Epoch 89/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.5257e-04 - accuracy: 0.9003
# Epoch 90/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.2076e-04 - accuracy: 0.8974
# Epoch 91/100
# 338/338 [==============================] - 1s 2ms/step - loss: 6.8974e-04 - accuracy: 0.9044
# Epoch 92/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.6054e-04 - accuracy: 0.9074
# Epoch 93/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.2401e-04 - accuracy: 0.9118
# Epoch 94/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.3141e-04 - accuracy: 0.9018
# Epoch 95/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.2163e-04 - accuracy: 0.9059
# Epoch 96/100
# 338/338 [==============================] - 1s 2ms/step - loss: 6.9107e-04 - accuracy: 0.9118
# Epoch 97/100
# 338/338 [==============================] - 1s 2ms/step - loss: 6.9950e-04 - accuracy: 0.9148
# Epoch 98/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.4278e-04 - accuracy: 0.9077
# Epoch 99/100
# 338/338 [==============================] - 1s 2ms/step - loss: 7.2997e-04 - accuracy: 0.9089
# Epoch 100/100
# 338/338 [==============================] - 1s 2ms/step - loss: 6.8501e-04 - accuracy: 0.9111

# %%
loss, accuracy = fmodel.evaluate(fk_x_test, fk_y_test)
print('Loss: %.8f, Accuracy: %.2f' % (loss, (accuracy*100)))
fmodel.save("./fkmodel")
# Out:
# 22/22 [==============================] - 0s 2ms/step - loss: 2.4315e-04 - accuracy: 0.9644
# Loss: 0.00024315, Accuracy: 96.44
# INFO:tensorflow:Assets written to: ./fkmodel\assets

# %% [markdown]
# # Learned Inverse Kinematics

# %% [markdown]
# ### Data Labels

# %%
ik_x_labels = ["M1X", "M1Y", "M2X", "M2Y", "M3X", "M3Y",
            "M4X", "M4Y", "M5X", "M5Y", "M6X", "M6Y",
            "M7X", "M7Y", "M8X", "M8Y", "M9X", "M9Y",
            "M10X", "M10Y"]
ik_y_labels = ["M1-PL", "M1-PR", "M2-PL", "M2-PR"]

ik_x_train, ik_y_train, ik_x_test, ik_y_test, ik_x_dim, ik_y_dim = segment_data(all_df_norm_shuffled, ik_x_labels, ik_y_labels, split_factor=0.8)

# %% [markdown]
# ### Model Structure

# %%
bmodel = Sequential()
bmodel.add(Dense(128, input_dim=ik_x_dim, activation='relu'))
bmodel.add(Dropout(0.2))
bmodel.add(Dense(64, activation='relu'))
bmodel.add(Dropout(0.2))
bmodel.add(Dense(32, activation='relu'))
bmodel.add(Dropout(0.2))
bmodel.add(Dense(16, activation='relu'))
bmodel.add(Dropout(0.2))
bmodel.add(Dense(ik_y_dim, activation='relu'))

bmodel.compile(loss='mse', optimizer='adam', metrics=['accuracy'])
bmodel.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 128)               2688
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 32)                2080
#
#  dropout_6 (Dropout)         (None, 32)                0
#
#  dense_8 (Dense)             (None, 16)                528
#
#  dropout_7 (Dropout)         (None, 16)                0
#
#  dense_9 (Dense)             (None, 4)                 68
#
# =================================================================
# Total params: 13,620
# Trainable params: 13,620
# Non-trainable params: 0
# _________________________________________________________________

# %%
historyb = bmodel.fit(ik_x_train, ik_y_train, epochs=100, batch_size=8)
# Out:
# Epoch 1/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0387 - accuracy: 0.3913
# Epoch 2/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0204 - accuracy: 0.5973
# Epoch 3/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0133 - accuracy: 0.6828
# Epoch 4/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0110 - accuracy: 0.6877
# Epoch 5/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0097 - accuracy: 0.6891
# Epoch 6/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0091 - accuracy: 0.7054
# Epoch 7/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0086 - accuracy: 0.7080
# Epoch 8/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0082 - accuracy: 0.7010
# Epoch 9/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0085 - accuracy: 0.6940
# Epoch 10/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0079 - accuracy: 0.7047
# Epoch 11/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0075 - accuracy: 0.7084
# Epoch 12/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0077 - accuracy: 0.7077
# Epoch 13/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0075 - accuracy: 0.7084
# Epoch 14/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0074 - accuracy: 0.7210
# Epoch 15/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0072 - accuracy: 0.7206
# Epoch 16/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0070 - accuracy: 0.7173
# Epoch 17/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0067 - accuracy: 0.7292
# Epoch 18/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0067 - accuracy: 0.7340
# Epoch 19/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0063 - accuracy: 0.7225
# Epoch 20/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0067 - accuracy: 0.7229
# Epoch 21/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0067 - accuracy: 0.7173
# Epoch 22/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0065 - accuracy: 0.7206
# Epoch 23/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0062 - accuracy: 0.7292
# Epoch 24/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0064 - accuracy: 0.7184
# Epoch 25/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0061 - accuracy: 0.7092
# Epoch 26/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0059 - accuracy: 0.7106
# Epoch 27/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0066 - accuracy: 0.7325
# Epoch 28/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0063 - accuracy: 0.7173
# Epoch 29/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0064 - accuracy: 0.7221
# Epoch 30/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0058 - accuracy: 0.7258
# Epoch 31/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0060 - accuracy: 0.7206
# Epoch 32/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0060 - accuracy: 0.7343
# Epoch 33/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0065 - accuracy: 0.7247
# Epoch 34/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0060 - accuracy: 0.7151
# Epoch 35/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0058 - accuracy: 0.7192
# Epoch 36/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0064 - accuracy: 0.7106
# Epoch 37/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0062 - accuracy: 0.7258
# Epoch 38/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0060 - accuracy: 0.7280
# Epoch 39/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0057 - accuracy: 0.7288
# Epoch 40/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0060 - accuracy: 0.7203
# Epoch 41/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0059 - accuracy: 0.7080
# Epoch 42/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0057 - accuracy: 0.7114
# Epoch 43/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0057 - accuracy: 0.7066
# Epoch 44/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0059 - accuracy: 0.7147
# Epoch 45/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0061 - accuracy: 0.7229
# Epoch 46/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0059 - accuracy: 0.7032
# Epoch 47/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0061 - accuracy: 0.7143
# Epoch 48/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0057 - accuracy: 0.7314
# Epoch 49/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0059 - accuracy: 0.7106
# Epoch 50/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0063 - accuracy: 0.7406
# Epoch 51/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0058 - accuracy: 0.7192
# Epoch 52/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0057 - accuracy: 0.7236
# Epoch 53/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0061 - accuracy: 0.7110
# Epoch 54/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0058 - accuracy: 0.7173
# Epoch 55/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0055 - accuracy: 0.7210
# Epoch 56/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0059 - accuracy: 0.7258
# Epoch 57/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0058 - accuracy: 0.7162
# Epoch 58/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0057 - accuracy: 0.7295
# Epoch 59/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0062 - accuracy: 0.7155
# Epoch 60/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0054 - accuracy: 0.7425
# Epoch 61/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0057 - accuracy: 0.7088
# Epoch 62/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0059 - accuracy: 0.6995
# Epoch 63/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0060 - accuracy: 0.7295
# Epoch 64/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0057 - accuracy: 0.7292
# Epoch 65/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0058 - accuracy: 0.7266
# Epoch 66/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0058 - accuracy: 0.7229
# Epoch 67/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0054 - accuracy: 0.7381
# Epoch 68/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0054 - accuracy: 0.7206
# Epoch 69/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0058 - accuracy: 0.7077
# Epoch 70/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0061 - accuracy: 0.7088
# Epoch 71/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0057 - accuracy: 0.7243
# Epoch 72/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0053 - accuracy: 0.7217
# Epoch 73/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0060 - accuracy: 0.7329
# Epoch 74/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0061 - accuracy: 0.7095
# Epoch 75/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0058 - accuracy: 0.7414
# Epoch 76/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0055 - accuracy: 0.7406
# Epoch 77/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0056 - accuracy: 0.7318
# Epoch 78/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0060 - accuracy: 0.7147
# Epoch 79/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0054 - accuracy: 0.7155
# Epoch 80/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0055 - accuracy: 0.7495
# Epoch 81/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0053 - accuracy: 0.7247
# Epoch 82/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0055 - accuracy: 0.7206
# Epoch 83/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0062 - accuracy: 0.7221
# Epoch 84/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0064 - accuracy: 0.7136
# Epoch 85/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0064 - accuracy: 0.7236
# Epoch 86/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0058 - accuracy: 0.7395
# Epoch 87/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0058 - accuracy: 0.7255
# Epoch 88/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0059 - accuracy: 0.7236
# Epoch 89/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0055 - accuracy: 0.7462
# Epoch 90/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0056 - accuracy: 0.7203
# Epoch 91/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0059 - accuracy: 0.7362
# Epoch 92/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0054 - accuracy: 0.7384
# Epoch 93/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0052 - accuracy: 0.7544
# Epoch 94/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0057 - accuracy: 0.7169
# Epoch 95/100
# 338/338 [==============================] - 1s 3ms/step - loss: 0.0056 - accuracy: 0.7458
# Epoch 96/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0067 - accuracy: 0.7310
# Epoch 97/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0058 - accuracy: 0.7292
# Epoch 98/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0061 - accuracy: 0.7158
# Epoch 99/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0053 - accuracy: 0.7166
# Epoch 100/100
# 338/338 [==============================] - 1s 2ms/step - loss: 0.0052 - accuracy: 0.7318

# %%
loss, accuracy = bmodel.evaluate(ik_x_test, ik_y_test)
print('Loss: %.8f, Accuracy: %.2f' % (loss, (accuracy*100)))
bmodel.save("./ikmodel")
# Out:
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0026 - accuracy: 0.7600
# Loss: 0.00262431, Accuracy: 76.00
# INFO:tensorflow:Assets written to: ./ikmodel\assets

# %% [markdown]
# # Plots and Analysis

# %%
def history_plot(historyf, historyb):
    plt.plot(historyf.history["loss"], label="Forward Kinematics Model")
    plt.plot(historyb.history["loss"], label="Inverse Kinematics Model")
    plt.legend()
    plt.xlabel("Epoch #")
    plt.ylabel("Loss (mse)")
    plt.title("Training Loss for Kinematics Models")
    # plt.savefig("data/training_backward.png")
history_plot(historyf, historyb)

# %%
def rescale(data, labels):
    ndata = []
    for idx, label in enumerate(labels):
        d = data[idx]
        min_val = norm_bounds.loc[0, label]
        max_val = norm_bounds.loc[1, label]
        rescaled_d = (d * (max_val - min_val)) + min_val
        ndata.append(rescaled_d)
    return np.array(ndata)

# %%
num_tests = len(fk_x_test)
def evaluate_markers(idx=(0,num_tests-1,1)):
    index = fk_x_test.index[idx]
    x_select = np.array(fk_x_test.loc[index, :]).reshape(1, -1)
    y_pred = fmodel.predict(x_select)
    cp = rescale(y_pred[0], fk_y_labels)
    ct = all_df.loc[index, fk_y_labels].to_numpy()
    
    xp = [0]
    xt = [0]
    yp = [0]
    yt = [0]
    
    for i in range(len(cp)):
        if i%2 == 0:
            xp.append(cp[i])
            xt.append(ct[i])
        else:
            yp.append(cp[i])
            yt.append(ct[i])
#     df["M1X-P"] = xp[0]
#     df["M1Y-P"] = yp[0]
    
    plt.plot(xt, yt, "-o", label="actual")
    plt.plot(xp, yp, "-o", label="predicted")
    plt.xlim([-20,20])
    plt.ylim([-1,39])
    plt.xlabel("x (cm)")
    plt.ylabel("y (cm)")
    plt.legend()
    plt.title("Predicted Markers vs. Actual Markers")
    plt.show()
        
interact(evaluate_markers)
# Out:
# (1, 48)
# 1/1 [==============================] - 0s 33ms/step
# interactive(children=(IntSlider(value=337, description='idx', max=674), Output()), _dom_classes=('widget-inter…
# <function __main__.evaluate_markers(idx=(0, 674, 1))>

# %%
# bmodel.save("/Volumes/Flash/basic_bmodel/")

# %%
num_tests = len(x_test)
def evaluate_markers(idx=(0,num_tests-1,1)):
    index = x_test.index[idx]
    x_select = np.array(x_test.loc[index, :]).reshape(1, -1)
    print(x_select)
    print(x_select.shape)
    y_pred = bmodel.predict(x_select)
    pp = rescale(y_pred[0], y_labels)
    pt = all_df.loc[index, y_labels].to_numpy()
    print(pp)
    print(pt)
    plt.plot([1,2], pt[0:2], "-o", label="actual M1", color="C0")
    plt.plot([3,4], pt[2:4], "-x", label="actual M2", color="C0")
    plt.plot([1,2], pp[0:2], "-o", label="predicted M1", color="C1")
    plt.plot([3,4], pp[2:4], "-x", label="predicted M2", color="C1")
    plt.ylim([95,120])
    plt.xlim([0.5,4.5])
    plt.xticks([1,2,3,4], ["P_1,1", "P_1,2", "P_2,1", "P_2,2"])
    plt.legend()
    plt.xlabel("Pressure Sensor")
    plt.ylabel("Pressure Value (kPa)")
    plt.show()
        
interact(evaluate_markers)

# %%
num_tests = len(x_test)
def evaluate_polynomial(idx=(0,num_tests-1,1)):
    index = x_test.index[idx]
    x_select = np.array(x_test.loc[index, :]).reshape(1, -1)
    p_pred = pmodel.predict(x_select)
    pp = rescale(p_pred[0], p_labels)
    pt = all_df.loc[index, p_labels].to_numpy()
    
    ap = np.flip(pp[:-1])
    dp = pp[-1]
    at = np.flip(pt[:-1])
    dt = pt[-1]
    
    polyp = np.poly1d(ap)
    polyt = np.poly1d(at)
    
    yp = np.linspace(0, dp)
    xp = polyp(yp)
    
    yt = np.linspace(0, dt)
    xt = polyt(yt)
    
    
    plt.plot(xt, yt, label="actual")
    plt.plot(xp, yp, label="predicted")
    plt.xlim([-20,20])
    plt.ylim([-1,39])
    plt.xlabel("x (cm)")
    plt.ylabel("y (cm)")
    plt.legend()
    plt.title("Predicted Markers vs. Actual Markers")
    plt.show()
        
interact(evaluate_polynomial)

# %%
errors = []
for idx in range(len(x_test)):
    index = x_test.index[idx]
    x_select = np.array(x_test.loc[index, :]).reshape(1, -1)
    y_pred = bmodel.predict(x_select)
    y_pred = rescale(y_pred[0], y_labels)
    y_select = all_df.loc[index, y_labels].to_numpy()
    diff = (y_pred - y_select)
    mse = (diff * diff).sum() / len(y_labels)
    rmse = math.sqrt(mse)
    errors.append((rmse, index))

# %%
errors.sort()
print(errors)

# %%
num_tests = len(x_test)
def evaluate_sort_markers(idx=(0,num_tests-1,1)):
    index = errors[idx][1]
    err = errors[idx][0]
    x_select = np.array(x_test.loc[index, :]).reshape(1, -1)
    y_pred = fmodel.predict(x_select)
    cp = rescale(y_pred[0], y_labels)
    ct = all_df.loc[index, y_labels].to_numpy()
    
    xp = [0]
    xt = [0]
    yp = [0]
    yt = [0]
    
    for i in range(len(cp)):
        if i%2 == 0:
            xp.append(cp[i])
            xt.append(ct[i])
        else:
            yp.append(cp[i])
            yt.append(ct[i])
    
    plt.plot(xt, yt, "-o", label="actual")
    plt.plot(xp, yp, "-o", label="predicted")
    plt.xlim([-20,20])
    plt.ylim([-1,39])
    plt.xlabel("x (cm)")
    plt.ylabel("y (cm)")
    plt.legend()
    plt.title("Predicted Markers vs. Actual Markers. RMSE: " + str(round(err,5)) + "cm")
    plt.show()
        
interact(evaluate_sort_markers)

# %%
just_errors = []
for e in errors:
    just_errors.append(e[0])
plt.hist(just_errors, bins=30)
plt.title("Histogram of Root Mean Squared Error for Forward Model")
plt.ylim([0,170])
plt.ylabel("Number of Predictions")
plt.xlabel("Root Mean Squared Error (cm)")
# plt.savefig("data/forward_error_histogram.png")

# %%
file_index = 9
data_index = 570
for idx, e in enumerate(errors):
    index = errors[idx][1]
    file_index_temp = all_df.loc[index, "file_index"]
    data_index_temp = all_df.loc[index, "data_index"]
    if file_index_temp == file_index and data_index_temp == data_index:
        break
#idx = 1157
index = errors[idx][1]
err = errors[idx][0]
print(index)
x_select = np.array(x_test.loc[index, :]).reshape(1, -1)
y_pred = fmodel.predict(x_select)
cp = rescale(y_pred[0], y_labels)
ct = all_df.loc[index, y_labels].to_numpy()

xp = [0]
xt = [0]
yp = [0]
yt = [0]

for i in range(len(cp)):
    if i%2 == 0:
        xp.append(cp[i])
        xt.append(ct[i])
    else:
        yp.append(cp[i])
        yt.append(ct[i])

plt.plot(xt, yt, "-o", label="actual")
plt.plot(xp, yp, "-o", label="predicted")
plt.xlim([-20,20])
plt.ylim([-1,39])
plt.xlabel("x (cm)")
plt.ylabel("y (cm)")
plt.legend()
plt.title("Predicted Markers vs. Actual Markers. RMSE: " + str(round(err,5)) + "cm")
pd.set_option("display.max_rows", None, "display.max_columns", None)
file_index = all_df.loc[index, "file_index"]
data_index = all_df.loc[index, "data_index"]
fname = "data/good" + str(file_index) + "_" + str(data_index) + "_2.png"
print(fname)
# plt.savefig(fname)

# %%
print(len(x_train))

# %%
num_tests = len(x_test)
def evaluate_sort_pressures(idx=(0,num_tests-1,1)):
    index = errors[idx][1]
    err = errors[idx][0]
    x_select = np.array(x_test.loc[index, :]).reshape(1, -1)
    y_pred = bmodel.predict(x_select)
    pp = rescale(y_pred[0], y_labels)
    pt = all_df.loc[index, y_labels].to_numpy()
    print(pp)
    print(pt)
    plt.plot([1,2], pt[0:2], "-o", label="actual M1", color="C0")
    plt.plot([3,4], pt[2:4], "-x", label="actual M2", color="C0")
    plt.plot([1,2], pp[0:2], "-o", label="predicted M1", color="C1")
    plt.plot([3,4], pp[2:4], "-x", label="predicted M2", color="C1")
    plt.ylim([95,120])
    plt.xlim([0.5,4.5])
    plt.xticks([1,2,3,4], ["P_1,1", "P_1,2", "P_2,1", "P_2,2"])
    plt.xlabel("Pressure Sensor")
    plt.ylabel("Pressure Value (kPa)")
    plt.legend()
    plt.title("Predicted Pressures vs. Actual Pressures. RMSE: " + str(round(err,3)) + "kPa")
    plt.show()
        
interact(evaluate_sort_pressures)

# %%
# file_index = 9
# data_index = 570
# for idx, e in enumerate(errors):
#     index = errors[idx][1]
#     file_index_temp = all_df.loc[index, "file_index"]
#     data_index_temp = all_df.loc[index, "data_index"]
#     if file_index_temp == file_index and data_index_temp == data_index:
#         break
idx = 1177
print(idx)
index = errors[idx][1]
err = errors[idx][0]
print(index)
x_select = np.array(x_test.loc[index, :]).reshape(1, -1)
y_pred = bmodel.predict(x_select)
pp = rescale(y_pred[0], y_labels)
pt = all_df.loc[index, y_labels].to_numpy()
print(pp)
print(pt)
plt.plot([1,2], pt[0:2], "-o", label="actual M1", color="C0")
plt.plot([3,4], pt[2:4], "-x", label="actual M2", color="C0")
plt.plot([1,2], pp[0:2], "-o", label="predicted M1", color="C1")
plt.plot([3,4], pp[2:4], "-x", label="predicted M2", color="C1")
plt.ylim([95,120])
plt.xlim([0.5,4.5])
plt.xticks([1,2,3,4], ["P_1,1", "P_1,2", "P_2,1", "P_2,2"])
plt.xlabel("Pressure Sensor")
plt.ylabel("Pressure Value (kPa)")
plt.legend()
plt.title("Predicted Pressures vs. Actual Pressures. RMSE: " + str(round(err,3)) + "kPa")
pd.set_option("display.max_rows", None, "display.max_columns", None)
file_index = all_df.loc[index, "file_index"]
data_index = all_df.loc[index, "data_index"]
fname = "data_pressures/bad" + str(file_index) + "_" + str(data_index) + ".png"
print(fname)
# plt.savefig(fname)

# %%
just_errors = []
for e in errors:
    just_errors.append(e[0])
plt.hist(just_errors, bins=30)
plt.title("Histogram of Root Mean Squared Error for Backward Model")
plt.ylim([0,170])
plt.ylabel("Number of predictions")
plt.xlabel("Root Mean Squared Error (kPa)")
# plt.savefig("data/backward_error_histogram.png")
